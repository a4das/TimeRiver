# %%
import time
import easygui

# File path
file_path = 'number.txt'

def read_number(file_path):
    with open(file_path, 'r') as f:
        return int(f.read().strip())

while True:
    number = read_number(file_path)
    result = easygui.msgbox(f"{number} sec left", title="TimeRiver")

    if result == "OK":
        break

    time.sleep(0.1)  # Refresh rate: 10 times per second

# %%
# Increased font size
import time
import easygui
#import tkinter

# File path
file_path = 'number.txt'

def read_number(file_path):
    with open(file_path, 'r') as f:
        return int(f.read().strip())

# Set global font size
root = tkinter.Tk()
default_font = tkinter.font.nametofont("TkDefaultFont")
default_font.configure(size=20)
root.option_add("*Font", default_font)

while True:
    number = read_number(file_path)
    result = easygui.msgbox(f"The number is {number}", title="Number Display")

    if result == "OK":
        break

    time.sleep(0.1)  # Refresh rate: 10 times per second

# %%
from datetime import datetime

# datetime(year, month, day, hour, minute, second, Microsecond)
a = datetime(2025, 2, 28, 23, 59, 59, 99999) # End date
g = datetime(datetime.now().year, datetime.now().month,  datetime.now().day, 
             datetime.now().hour, datetime.now().minute, datetime.now().second, 
             datetime.now().microsecond)     # Now

# returns a timedelta object
c = a-g
print(c.total_seconds(), 'seconds left')
# Out:
# 55334797.130181 seconds left

# %%
# import all required libraries
import time
import easygui
from datetime import datetime

'''
# File path
file_path = 'number.txt'

def read_number(file_path):
    with open(file_path, 'r') as f:
        return int(f.read().strip())
''' # to be used later

a = datetime(2025, 2, 28, 23, 59, 59, 99999) # End date

while True:
    #number = read_number(file_path) # to be used later
    
    g = datetime(datetime.now().year, datetime.now().month,  datetime.now().day, 
             datetime.now().hour, datetime.now().minute, datetime.now().second, 
             datetime.now().microsecond)     # Now
    number = (a-g).total_seconds()
    result = easygui.msgbox(f"{number} sec left", title="TimeRiver")

    if result == "OK":
        break

    time.sleep(0.1)  # Refresh rate: 100 times per second

# %%
datetime.datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-09a0fa0244be> in <module>
# ----> 1 datetime.datetime
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
# Library

# %%
from datetime import datetime
def get_datetime_components():
    now = datetime.now()
    components = [now.year, now.month, now.day, now.hour, now.minute, now.second, now.microsecond]
    return components
get_datetime_components()
# datetime(year, month, day, hour, minute, second)
g = datetime(datetime.now().year, datetime.now().month,  datetime.now().day, 
             datetime.now().hour, datetime.now().minute, datetime.now().second, 
             datetime.now().microsecond)
g
# Out:
# datetime.datetime(2023, 5, 30, 13, 6, 51, 166325)

# %%
a
# Out:
# datetime.datetime(2025, 2, 28, 23, 59, 59)

# %% [markdown]
# # Tk

# %%
import tkinter as tk
from datetime import datetime

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)

def update_time():
    if not stop:
        g = datetime.now()
        number = (a-g).total_seconds()
        # Update the time display
        label.config(text = f"{number} sec left")
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def stop_timer():
    global stop
    stop = True

# Create the main window
root = tk.Tk()

# Variable to indicate whether to stop the timer
stop = False

# Create a label to display the time
label = tk.Label(root, font=("Arial", 30))
label.pack()

# Create a button to stop the timer
button = tk.Button(root, text="Stop", command=stop_timer)
button.pack()

# Start the countdown
update_time()

# Start the main event loop
root.mainloop()

# %%
import tkinter as tk
from datetime import datetime

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)

def update_time():
    if not stop:
        g = datetime.now()
        number = (a-g).total_seconds()
        # Update the time display
        label.config(text = f"{number} \nsec left")
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def stop_timer():
    global stop
    stop = True

# Create the main window
root = tk.Tk()

# Set window size
root.geometry('500x500')  # width x height

# Variable to indicate whether to stop the timer
stop = False

# Create a label to display the time
label = tk.Label(root, font=("Arial", 30))
label.pack()

# Create a button to stop the timer
button = tk.Button(root, text="Stop", command=stop_timer)
button.pack()

# Start the countdown
update_time()

# Start the main event loop
root.mainloop()

# %%
import tkinter as tk
from datetime import datetime

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)

def update_time():
    if not stop:
        g = datetime.now()
        number = (a-g).total_seconds()
        # Update the time display
        #label.config(text = f"{number:16.2f} sec left")
        label.config(text = f"{number:,.3f} sec left")
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def stop_timer():
    global stop
    stop = True

# Create the main window
root = tk.Tk()

# Set window size
root.geometry('500x500')  # width x height

# Variable to indicate whether to stop the timer
stop = False

# Create a label to display the time
label = tk.Label(root, font=("Arial", 30), anchor='w')
label.grid(row=0, column=0)

# Create a button to stop the timer
button = tk.Button(root, text="Stop", command=stop_timer)
button.grid(row=1, column=0)

# Start the countdown
update_time()

# Start the main event loop
root.mainloop()

# %%
import tkinter as tk
from datetime import datetime

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)

def update_time():
    if not stop:
        g = datetime.now()
        number = (a-g).total_seconds()
        # Update the time display
        label.config(text = f"{number:,.2f} sec left")
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def stop_timer():
    global stop
    stop = True

def configure_window(event):
    # Check if the window is in the normal state (not maximized)
    if root.state() == 'normal':
        # Set the window size to 600x600
        root.geometry('600x600')

# Create the main window
root = tk.Tk()

# Maximize the window
root.state('zoomed')

# Bind the configure event to the configure_window function
root.bind('<Configure>', configure_window)

# Variable to indicate whether to stop the timer
stop = False

# Create a label to display the time
label = tk.Label(root, font=("Arial", 30), anchor='center')
label.place(relx=0.5, rely=0.5, anchor='center')

# Create a button to stop the timer
button = tk.Button(root, text="Stop", command=stop_timer)
button.place(relx=0.5, rely=0.6, anchor='center')

# Start the countdown
update_time()

# Start the main event loop
root.mainloop()

# %%
import tkinter as tk
from datetime import datetime

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)

def update_time():
    if not stop:
        g = datetime.now()
        number = (a-g).total_seconds()
        # Update the time display
        label.config(text = f"{number:,.2f} sec left")
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def stop_timer():
    global stop
    stop = True

def configure_window(event):
    # Check if the window is in the normal state (not maximized)
    if root.state() == 'normal':
        # Set the window size to 600x600
        root.geometry('600x600')

def start_move(event):
    global x, y
    x = event.x
    y = event.y

def stop_move(event):
    global x, y
    x = None
    y = None

def do_move(event):
    dx = event.x - x
    dy = event.y - y
    root.geometry(f"+{root.winfo_x() + dx}+{root.winfo_y() + dy}")

# Create the main window
root = tk.Tk()

# Maximize the window
root.state('zoomed')

# Bind the configure event to the configure_window function
root.bind('<Configure>', configure_window)

# Bind the mouse movement events to the respective functions
root.bind('<ButtonPress-1>', start_move)
root.bind('<ButtonRelease-1>', stop_move)
root.bind('<B1-Motion>', do_move)

# Variable to indicate whether to stop the timer
stop = False

# Create a label to display the time
label = tk.Label(root, font=("Arial", 30), anchor='center')
label.place(relx=0.5, rely=0.5, anchor='center')

# Create a button to stop the timer
button = tk.Button(root, text="Stop", command=stop_timer)
button.place(relx=0.5, rely=0.6, anchor='center')

# Start the countdown
update_time()

# Start the main event loop
root.mainloop()

# %%
import tkinter as tk
from datetime import datetime

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)

def update_time():
    if not stop:
        g = datetime.now()
        number = (a-g).total_seconds()
        # Update the time display
        label.config(text = f"{number:,.2f} sec left")
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def stop_timer():
    global stop
    stop = True

def configure_window(event):
    # Check if the window is in the normal state (not maximized)
    if root.state() == 'normal':
        # Set the window size to 600x600
        root.geometry('600x600')

# Create the main window
root = tk.Tk()

# Maximize the window
root.state('zoomed')

# Make the window resizable
root.resizable(True, True)

# Bind the configure event to the configure_window function
root.bind('<Configure>', configure_window)

# Variable to indicate whether to stop the timer
stop = False

# Create a label to display the time
label = tk.Label(root, font=("Arial", 30), anchor='center')
label.place(relx=0.5, rely=0.5, anchor='center')

# Create a button to stop the timer
button = tk.Button(root, text="Stop", command=stop_timer)
button.place(relx=0.5, rely=0.6, anchor='center')

# Start the countdown
update_time()

# Start the main event loop
root.mainloop()

# %%
import tkinter as tk
from datetime import datetime

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)
b = datetime(2021, 3, 1,   0,  0,  0, 0)
tot = (a-b).total_seconds()/60
print(tot)

def update_time():
    if not stop:
        g = datetime.now()
        number = ((a-g).total_seconds())/60
        # Update the time display
        label.config(text = f"{number:,.3f} mins left")
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def exit_program():
    global root
    root.destroy()

def configure_window(event):
    # Check if the window is in the normal state (not maximized)
    if root.state() == 'normal':
        # Set the window size to 600x600
        root.geometry('600x600')

# Create the main window
root = tk.Tk()
root.title("TimeRiver")
# Maximize the window
root.state('zoomed')

# Make the window resizable
root.resizable(True, True)

# Set the background color of the window to light red
root.configure(bg='#FFCCCC')

# Bind the configure event to the configure_window function
root.bind('<Configure>', configure_window)

# Variable to indicate whether to stop the timer
stop = False

# Create a label to display the time, with a light red background
label = tk.Label(root, font=("Arial", 30), anchor='center', bg='#FFCCCC')
label.place(relx=0.5, rely=0.5, anchor='center')

# Create a button to stop the timer, with a light red background
button = tk.Button(root, text="Exit", command=exit_program, bg='#FFCCCC')
button.place(relx=0.5, rely=0.6, anchor='center')

# Start the countdown
update_time()

# Start the main event loop
root.mainloop()
# Out:
# 2103839.984999983

# %%
# with Pie chart
import tkinter as tk
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)
b = datetime(2021, 3, 1,   0,  0,  0, 0)
tot = (a-b).total_seconds()/60
g = datetime.now()
print(((a-g).total_seconds()/60)/tot)

def update_time():
    if not stop:
        g = datetime.now()
        number = ((a-g).total_seconds())/60
        # Update the time display
        label.config(text = f"{number:,.3f} mins left")
        # Update the pie chart
        ax.clear()
        ax.pie([number, tot-number], colors=['cyan', 'white'], labels=['Elapsed', 'Remaining'], startangle=90, counterclock=False)
        canvas.draw()
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def stop_timer():
    global stop
    stop = True

def configure_window(event):
    # Check if the window is in the normal state (not maximized)
    if root.state() == 'normal':
        # Set the window size to 600x600
        root.geometry('600x600')

# Create the main window
root = tk.Tk()

# Maximize the window
root.state('zoomed')

# Make the window resizable
root.resizable(True, True)

# Set the background color of the window to light red
root.configure(bg='#FFCCCC')

# Bind the configure event to the configure_window function
root.bind('<Configure>', configure_window)

# Variable to indicate whether to stop the timer
stop = False

# Create a label to display the time, with a light red background
label = tk.Label(root, font=("Arial", 30), anchor='center', bg='#FFCCCC')
label.place(relx=0.5, rely=0.5, anchor='center')

# Create a button to stop the timer, with a light red background
button = tk.Button(root, text="Stop", command=stop_timer, bg='#FFCCCC')
button.place(relx=0.5, rely=0.6, anchor='center')

# Create a Matplotlib figure and an axes to hold the pie chart
fig, ax = plt.subplots()
canvas = FigureCanvasTkAgg(fig, master=root)  # A tk.DrawingArea.
canvas.get_tk_widget().place(relx=0.5, rely=0.3, anchor='center')

# Start the countdown
update_time()

# Start the main event loop
root.mainloop()
# Out:
# 0.4382385074316733

# %%
import tkinter as tk
from datetime import datetime

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)
b = datetime(2021, 3, 1,   0,  0,  0, 0)
tot = (a-b).total_seconds()/60

def update_time():
    if not stop:
        g = datetime.now()
        number = ((a-g).total_seconds())/60
        # Update the time display
        label.config(text = f"{number:,.3f} mins left")
        # Update the pie chart
        canvas.delete("all")
        canvas.create_arc(50, 50, 250, 250, start=0, extent = (number/tot)*360, fill="cyan")
        canvas.create_arc(50, 50, 250, 250, start=(number/tot)*360, extent = 360-(number/tot)*360, fill="white")
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def stop_timer():
    global stop
    stop = True

def configure_window(event):
    # Check if the window is in the normal state (not maximized)
    if root.state() == 'normal':
        # Set the window size to 600x600
        root.geometry('600x600')

# Create the main window
root = tk.Tk()

# Maximize the window
root.state('zoomed')

# Make the window resizable
root.resizable(True, True)

# Set the background color of the window to light red
root.configure(bg='#FFCCCC')

# Bind the configure event to the configure_window function
root.bind('<Configure>', configure_window)

# Variable to indicate whether to stop the timer
stop = False

# Create a label to display the time, with a light red background
label = tk.Label(root, font=("Arial", 30), anchor='center', bg='#FFCCCC')
label.place(relx=0.5, rely=0.5, anchor='center')

# Create a button to stop the timer, with a light red background
button = tk.Button(root, text="Stop", command=stop_timer, bg='#FFCCCC')
button.place(relx=0.5, rely=0.6, anchor='center')

# Create a canvas to hold the pie chart
canvas = tk.Canvas(root, width=300, height=300, bg='white')
canvas.place(relx=0.5, rely=0.3, anchor='center')

# Start the countdown
update_time()

# Start the main event loop
root.mainloop()

# %%
import tkinter as tk
from datetime import datetime
from math import ceil

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)
b = datetime(2021, 3, 1,   0,  0,  0, 0)
tot = (a-b).total_seconds()/60
print(tot)

def update_time():
    if not stop:
        g = datetime.now()
        number = ((a-g).total_seconds())/60
        # Update the time display
        label.config(text = f"{number:,.3f} mins left")
        # Update the hour bar
        update_hour_bar(g.hour + g.minute/60)
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def exit_program():
    global root
    root.destroy()

def configure_window(event):
    # Check if the window is in the normal state (not maximized)
    if root.state() == 'normal':
        # Set the window size to 600x600
        root.geometry('600x600')

def update_hour_bar(hour):
    for i in range(24):
        if i < hour:
            # Past hours are white
            hour_bar.itemconfig(i+1, fill='white')
        elif i == round(hour):
            # The current hour fades from green to white
            fraction = hour - i
            intensity = min(255, max(0, ceil(255 * (1 - fraction))))
            color = f'#00{intensity:02x}00'
            hour_bar.itemconfig(i+1, fill=color)
        else:
            # Future hours are green
            hour_bar.itemconfig(i+1, fill='green')

# Create the main window
root = tk.Tk()
root.title("TimeRiver")
# Maximize the window
root.state('zoomed')

# Make the window resizable
root.resizable(True, True)

# Set the background color of the window to light red
root.configure(bg='#FFCCCC')

# Bind the configure event to the configure_window function
root.bind('<Configure>', configure_window)

# Variable to indicate whether to stop the timer
stop = False

# Create a label to display the time, with a light red background
label = tk.Label(root, font=("Arial", 30), anchor='center', bg='#FFCCCC')
label.place(relx=0.5, rely=0.5, anchor='center')

# Create a button to stop the timer, with a light red background
button = tk.Button(root, text="Exit", command=exit_program, bg='#FFCCCC')
button.place(relx=0.5, rely=0.6, anchor='center')

# Create an hour bar on the right side of the window
hour_bar = tk.Canvas(root, width=30, height=500, bg='white')
hour_bar.place(relx=0.95, rely=0.5, anchor='center')
for i in range(24):
    hour_bar.create_rectangle(0, i*500/24, 30, (i+1)*500/24 - 1, fill='green', outline='black')

# Start the countdown
update_time()

# Start the main event loop
root.mainloop()
# Out:
# 2103839.984999983

# %%
import tkinter as tk
from datetime import datetime
from math import ceil

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)
b = datetime(2021, 3, 1,   0,  0,  0, 0)
tot = (a-b).total_seconds()/60
print(tot)

def update_time():
    if not stop:
        g = datetime.now()
        number = ((a-g).total_seconds())/60
        # Update the time display
        label.config(text = f"{number:,.3f} mins left")
        # Update the hour bar
        update_hour_bar(g.hour + g.minute/60)
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)

def exit_program():
    global root
    root.destroy()

def configure_window(event):
    # Check if the window is in the normal state (not maximized)
    if root.state() == 'normal':
        # Set the window size to 600x600
        root.geometry('600x600')
    draw_grid()

def update_hour_bar(hour):
    for i in range(24):
        if i < hour:
            # Past hours are white
            hour_bar.itemconfig(i+1, fill='white')
        elif i == round(hour):
            # The current hour fades from green to white
            fraction = hour - i
            intensity = min(255, max(0, ceil(255 * (1 - fraction))))
            color = f'#00{intensity:02x}00'
            hour_bar.itemconfig(i+1, fill=color)
        else:
            # Future hours are green
            hour_bar.itemconfig(i+1, fill='green')

def draw_grid(event=None):
    grid_canvas.delete('all')  # clear the previous grid
    width = grid_canvas.winfo_width()
    height = grid_canvas.winfo_height()
    for i in range(0, width, 50):  # adjust the step size as per your requirement
        grid_canvas.create_line([(i, 0), (i, height)], fill='#d3d3d3', dash=(2, 5))
    for i in range(0, height, 50):  # adjust the step size as per your requirement
        grid_canvas.create_line([(0, i), (width, i)], fill='#d3d3d3', dash=(2, 5))

# Create the main window
root = tk.Tk()
root.title("TimeRiver")
# Maximize the window
root.state('zoomed')

# Make the window resizable
root.resizable(True, True)

# Set the background color of the window to light red
root.configure(bg='#FFCCCC')

# Bind the configure event to the configure_window function
root.bind('<Configure>', configure_window)

# Variable to indicate whether to stop the timer
stop = False

##############################################################################################
#                                           Home Page                                        #
##############################################################################################
# Create a canvas for the grid
grid_canvas = tk.Canvas(root, bg='#FFDCDC')  # Same background color as the root window
grid_canvas.place(x=0, y=0, relwidth=1, relheight=1)


# Create a label to display the time, with a light red background
label = tk.Label(root, font=("Arial", 30), anchor='center', bg='#FFCCCC')
label.place(relx=0.5, rely=0.5, anchor='center')

button = tk.Button(root, text="Exit", command=exit_program, bg='#FFCCCC')
button.place(relx=0.5, rely=0.6, anchor='center')

# Create an hour bar on the right side of the window
hour_bar = tk.Canvas(root, width=30, height=500, bg='white')
hour_bar.place(relx=0.95, rely=0.5, anchor='center')
for i in range(24):
    hour_bar.create_rectangle(0, i*500/24, 30, (i+1)*500/24 - 1, fill='green', outline='black')

# Start the countdown
update_time()

# Draw the grid
draw_grid()

##############################################################################################
#                                           Home Page end                                    #
##############################################################################################


# Start the main event loop
root.mainloop()
# Out:
# 2103839.984999983

# %%
import tkinter as tk

def show_home():
    home_frame.pack(fill='both', expand=True)
    stats_frame.pack_forget()

def show_stats():
    stats_frame.pack(fill='both', expand=True)
    home_frame.pack_forget()

root = tk.Tk()

# Create a frame for the home page
home_frame = tk.Frame(root)
# Add some content to the home frame
home_label = tk.Label(home_frame, text="Home page")
home_label.pack()

# Create a frame for the stats page
stats_frame = tk.Frame(root)
# Add some content to the stats frame
stats_label = tk.Label(stats_frame, text="Stats page")
stats_label.pack()

# Create the buttons
home_button = tk.Button(root, text="Home", command=show_home)
stats_button = tk.Button(root, text="Stats", command=show_stats)

# Pack the buttons at the top of the window
home_button.pack(side='left')
stats_button.pack(side='left')

# Start on the home page
show_home()

root.mainloop()

# %%
import tkinter as tk
from datetime import datetime
from math import ceil

# End date
a = datetime(2025, 2, 28, 23, 59, 59, 99999)
b = datetime(2021, 3, 1,   0,  0,  0, 0)
tot = (a-b).total_seconds()/60
print(tot)

def update_time():
    if not stop:
        g = datetime.now()
        number = ((a-g).total_seconds())/60
        # Update the time display
        label.config(text = f"{number:,.3f} mins left")
        # Update the hour bar
        update_hour_bar(g.hour + g.minute/60)
        # Reschedule the function to run again after 100ms
        root.after(100, update_time)
        # Update the hour bar
        update_hour_bar(g.hour + g.minute/60)


def exit_program():
    global root
    root.destroy()

def configure_window(event):
    # Check if the window is in the normal state (not maximized)
    if root.state() == 'normal':
        # Set the window size to 600x600
        root.geometry('600x600')
    draw_grid()

def update_hour_bar(hour):
    for i in range(24):
        if i < hour:
            # Past hours are white
            hour_bar.itemconfig(i+1, fill='white')
        elif i == round(hour):
            # The current hour fades from green to white
            fraction = hour - i
            intensity = min(255, max(0, ceil(255 * (1 - fraction))))
            color = f'#00{intensity:02x}00'
            hour_bar.itemconfig(i+1, fill=color)
        else:
            # Future hours are green
            hour_bar.itemconfig(i+1, fill='green')

def draw_grid(event=None):
    grid_canvas.delete('all')  # clear the previous grid
    width = grid_canvas.winfo_width()
    height = grid_canvas.winfo_height()
    for i in range(0, width, 50):  # adjust the step size as per your requirement
        grid_canvas.create_line([(i, 0), (i, height)], fill='#d3d3d3', dash=(2, 5))
    for i in range(0, height, 50):  # adjust the step size as per your requirement
        grid_canvas.create_line([(0, i), (width, i)], fill='#d3d3d3', dash=(2, 5))

def show_home():
    home_frame.pack(fill='both', expand=True)
    stats_frame.pack_forget()
    customize_frame.pack_forget()

def show_stats():
    stats_frame.pack(fill='both', expand=True)
    home_frame.pack_forget()
    customize_frame.pack_forget()

def show_customize():
    customize_frame.pack(fill='both', expand=True)
    home_frame.pack_forget()
    stats_frame.pack_forget()

# Create the main window
root = tk.Tk()
root.title("TimeRiver")
# Maximize the window
root.state('zoomed')

# Make the window resizable
root.resizable(True, True)

# Set the background color of the window to light red
root.configure(bg='#FFCCCC')

# Bind the configure event to the configure_window function
root.bind('<Configure>', configure_window)

# Variable to indicate whether to stop the timer
stop = False

########################################### BUttons #########################################

# Create a frame for the buttons
button_frame = tk.Frame(root, bg='#FFCCCC')
button_frame.pack(fill='x')

# Create Home, Stats, and Customize buttons
button = tk.Button(button_frame, text="Home", command=show_home)
stats_button = tk.Button(button_frame, text="Stats", command=show_stats)
customize_button = tk.Button(button_frame, text="©", command=show_customize)

# Instead of packing the buttons to the side, we'll use grid to place them in the center of the frame.
button.grid(row=0, column=1, sticky='ew')
stats_button.grid(row=0, column=2, sticky='ew')
customize_button.grid(row=0, column=3, sticky='ew')

# Configure the columns to have equal weight
button_frame.grid_columnconfigure(1, weight=1)
button_frame.grid_columnconfigure(2, weight=1)
button_frame.grid_columnconfigure(3, weight=1)


##############################################################################################
#                                           Home Page                                        #
##############################################################################################

# Create a frame for the home page
# Create a frame for the home page
home_frame = tk.Frame(root, bg='#FFCCCC')
grid_canvas = tk.Canvas(home_frame, bg='#FFDCDC')  # Same background color as the root window
grid_canvas.place(x=0, y=0, relwidth=1, relheight=1)
label = tk.Label(home_frame, font=("Arial", 30), anchor='center', bg='#FFCCCC')
label.place(relx=0.5, rely=0.5, anchor='center')

button = tk.Button(home_frame, text="Exit", command=exit_program, bg='#FFCCCC')
button.place(relx=0.5, rely=0.6, anchor='center')

hour_bar = tk.Canvas(home_frame, width=30, height=500, bg='white')
hour_bar.place(relx=0.95, rely=0.5, anchor='center')
for i in range(24):
    hour_bar.create_rectangle(0, i*500/24, 30, (i+1)*500/24 - 1, fill='green', outline='black')


##############################################################################################
#                                           Stat Page                                        #
##############################################################################################

# Create a frame for the stats page
stats_frame = tk.Frame(root, bg='#FFCCCC')
stats_label = tk.Label(stats_frame, text="Stats page", font=("Arial", 30), bg='#FFCCCC')
stats_label.pack()

##############################################################################################
#                                           Customize Page                                   #
##############################################################################################

# Create a frame for the customize page
customize_frame = tk.Frame(root, bg='#FFCCCC')
customize_label = tk.Label(customize_frame, text="Customize page", font=("Arial", 30), bg='#FFCCCC')
customize_label.pack()

# Start the countdown
update_time()

# Draw the grid
draw_grid()

# Show the home page by default
show_home()

# Start the main event loop
root.mainloop()
# Out:
# 2103839.984999983
